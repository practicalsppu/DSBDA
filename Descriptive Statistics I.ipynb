# %%
import pandas as pd
df = pd.read_csv("P2.csv")

# %%
df.head()
# Out:
#    id age_group  income
# 0   1     18-25   30000
# 1   2     26-35   45000
# 2   3     18-25   32000
# 3   4     36-45   50000
# 4   5     26-35   47000

# %%
summary = df.groupby('age_group')['income'].agg(['mean', 'median', 'min', 'max', 'std'])

# %%
summary
# Out:
#               mean   median    min    max          std
# age_group
# 18-25      31000.0  31000.0  30000  32000  1414.213562
# 26-35      46000.0  46000.0  45000  47000  1414.213562
# 36-45      50000.0  50000.0  50000  50000          NaN

# %%
from sklearn.datasets import load_iris
data = load_iris()
df = pd.DataFrame(data=data.data, columns=data.feature_names)
df['target'] = data.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
sns.histplot(df['sepal length (cm)'], bins=20, kde=True)
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Count'>

# %%
sns.barplot(x=df['target'], y=df['sepal length (cm)'])
# Out:
# <Axes: xlabel='target', ylabel='sepal length (cm)'>

# %%
df.describe(percentiles=[0.25,0.5])
# Out:
#        sepal length (cm)  sepal width (cm)  ...  petal width (cm)      target
# count         150.000000        150.000000  ...        150.000000  150.000000
# mean            5.843333          3.057333  ...          1.199333    1.000000
# std             0.828066          0.435866  ...          0.762238    0.819232
# min             4.300000          2.000000  ...          0.100000    0.000000
# 25%             5.100000          2.800000  ...          0.300000    0.000000
# 50%             5.800000          3.000000  ...          1.300000    1.000000
# max             7.900000          4.400000  ...          2.500000    2.000000
#
# [7 rows x 5 columns]
